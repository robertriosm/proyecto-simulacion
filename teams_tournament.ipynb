# %% [markdown]
# ## Combinations for the tournament's matches between teams

# %%
import pandas as pd

# %% [markdown]
# #### cargar datos de la temporada 2023

# %%
df = pd.read_csv('Team Comp vs Opp Comp_the big cheese_data.csv')
df = df[df["Season"] > 2022]
df
# Out:
#                      team_name opponent (the big cheese) Result  \
# 413            Boston Uprising           Houston Outlaws   Loss
# 414            Boston Uprising             Vegas Eternal   Loss
# 415             Florida Mayhem           Boston Uprising   Loss
# 416           Guangzhou Charge          Shanghai Dragons    Win
# 417            Houston Outlaws            Florida Mayhem    Win
# ...                        ...                       ...    ...
# 848802      Washington Justice    Los Angeles Gladiators   Loss
# 848803              Trick Room          Vancouver Titans   Loss
# 848809      New York Excelsior        Washington Justice   Loss
# 848814      Washington Justice           Boston Uprising   Loss
# 848816  Los Angeles Gladiators           Boston Uprising   Loss
#
#                    map_name  Season
# 413     Antarctic Peninsula    2023
# 414     Antarctic Peninsula    2023
# 415     Antarctic Peninsula    2023
# 416     Antarctic Peninsula    2023
# ...

# %%
team_names = set(df["team_name"])
team_names
# Out:
# {'Atlanta Reign',
#  'Boston Uprising',
#  'Dallas Fuel',
#  'Dreamers',
#  'Florida Mayhem',
#  'Guangzhou Charge',
#  'Hangzhou Spark',
#  'Houston Outlaws',
#  'London Spitfire',
#  'Los Angeles Gladiators',
#  'Los Angeles Valiant',
#  'New York Excelsior',
#  'O2 Blast',
#  'PANTHERA',
#  'Poker Face',
#  'Redbird Esports',
#  'Rhodes',
#  'Saints',
#  'San Francisco Shock',
#  'Seoul Dynasty',
#  'Seoul Infernal',
#  'Shanghai Dragons',
#  'Sin Prisa Gaming',
#  'Team Peps',
#  'Timeless',
#  'Toronto Defiant',
#  'Trick Room',
#  'Twisted Minds',
#  'Vancouver Titans',
#  'Vegas Eternal',
#  'WISP',
#  'Washington Justice'}

# %%
len(team_names)
# Out:
# 32

# %%
from itertools import combinations
teams_matches = list(combinations(team_names,r=2))
teams_matches
# Out:
# [('Florida Mayhem', 'Washington Justice'),
#  ('Florida Mayhem', 'Seoul Infernal'),
#  ('Florida Mayhem', 'WISP'),
#  ('Florida Mayhem', 'Saints'),
#  ('Florida Mayhem', 'Rhodes'),
#  ('Florida Mayhem', 'San Francisco Shock'),
#  ('Florida Mayhem', 'Sin Prisa Gaming'),
#  ('Florida Mayhem', 'O2 Blast'),
#  ('Florida Mayhem', 'Twisted Minds'),
#  ('Florida Mayhem', 'Hangzhou Spark'),
#  ('Florida Mayhem', 'Timeless'),
#  ('Florida Mayhem', 'Vancouver Titans'),
#  ('Florida Mayhem', 'New York Excelsior'),
#  ('Florida Mayhem', 'Toronto Defiant'),
#  ('Florida Mayhem', 'PANTHERA'),
#  ('Florida Mayhem', 'Atlanta Reign'),
#  ('Florida Mayhem', 'Trick Room'),
#  ('Florida Mayhem', 'London Spitfire'),
#  ('Florida Mayhem', 'Dallas Fuel'),
#  ('Florida Mayhem', 'Shanghai Dragons'),
#  ('Florida Mayhem', 'Boston Uprising'),
#  ('Florida Mayhem', 'Los Angeles Valiant'),
#  ('Florida Mayhem', 'Seoul Dynasty'),
#  ('Florida Mayhem', 'Guangzhou Charge'),
#  ('Florida Mayhem', 'Vegas Eternal'),
# ...

# %%
# with open("result.txt", mode="w", encoding="utf-8") as f:
#     for i in teams_matches:
#         f.write(f"{i}\n")
# f.close()

# %%
len(teams_matches)
# Out:
# 496
