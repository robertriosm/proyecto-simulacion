# %% [markdown]
# ## Combinations for the tournament's matches between teams

# %%
import pandas as pd

# %%
df = pd.read_csv('Team Comp vs Opp Comp_the big cheese_data.csv')
df
# Out:
#                      team_name opponent (the big cheese) Result  \
# 0                Seoul Dynasty           Chengdu Hunters    Win
# 1           Washington Justice        New York Excelsior    Win
# 2                Atlanta Reign            Florida Mayhem    Win
# 3                  Dallas Fuel           London Spitfire    Win
# 4               Florida Mayhem             Vegas Eternal    Win
# ...                        ...                       ...    ...
# 848812         London Spitfire            Hangzhou Spark   Loss
# 848813     San Francisco Shock        Washington Justice   Loss
# 848814      Washington Justice           Boston Uprising   Loss
# 848815          Florida Mayhem             Seoul Dynasty   Loss
# 848816  Los Angeles Gladiators           Boston Uprising   Loss
#
#                    map_name  Season
# 0                     Ilios    2022
# 1                     Ilios    2022
# 2             Lijiang Tower    2022
# 3             Lijiang Tower    2022
# 4             Lijiang Tower    2022
# ...                     ...     ...
# 848812        Lijiang Tower    2022
# 848813                Nepal    2022
# 848814                Ilios    2023
# 848815                Ilios    2022
# 848816  Antarctic Peninsula    2023
#
# [848817 rows x 5 columns]

# %%
team_names = set(df["team_name"])
team_names
# Out:
# {'Atlanta Reign',
#  'Boston Uprising',
#  'Chengdu Hunters',
#  'Dallas Fuel',
#  'Dreamers',
#  'Florida Mayhem',
#  'Guangzhou Charge',
#  'Hangzhou Spark',
#  'Houston Outlaws',
#  'London Spitfire',
#  'Los Angeles Gladiators',
#  'Los Angeles Valiant',
#  'New York Excelsior',
#  'O2 Blast',
#  'PANTHERA',
#  'Poker Face',
#  'Redbird Esports',
#  'Rhodes',
#  'Saints',
#  'San Francisco Shock',
#  'Seoul Dynasty',
#  'Seoul Infernal',
#  'Shanghai Dragons',
#  'Sin Prisa Gaming',
#  'Team Peps',
#  'Timeless',
#  'Toronto Defiant',
#  'Trick Room',
#  'Twisted Minds',
#  'Vancouver Titans',
#  'Vegas Eternal',
#  'WISP',
#  'Washington Justice'}

# %%
len(team_names)
# Out:
# 33

# %%
from itertools import combinations
teams_matches = list(combinations(team_names,r=2))
teams_matches
# Out:
# [('Toronto Defiant', 'Vancouver Titans'),
#  ('Toronto Defiant', 'Twisted Minds'),
#  ('Toronto Defiant', 'Trick Room'),
#  ('Toronto Defiant', 'Washington Justice'),
#  ('Toronto Defiant', 'Dallas Fuel'),
#  ('Toronto Defiant', 'Seoul Infernal'),
#  ('Toronto Defiant', 'Redbird Esports'),
#  ('Toronto Defiant', 'Dreamers'),
#  ('Toronto Defiant', 'Boston Uprising'),
#  ('Toronto Defiant', 'London Spitfire'),
#  ('Toronto Defiant', 'Shanghai Dragons'),
#  ('Toronto Defiant', 'Chengdu Hunters'),
#  ('Toronto Defiant', 'Guangzhou Charge'),
#  ('Toronto Defiant', 'PANTHERA'),
#  ('Toronto Defiant', 'Los Angeles Gladiators'),
#  ('Toronto Defiant', 'Rhodes'),
#  ('Toronto Defiant', 'Sin Prisa Gaming'),
#  ('Toronto Defiant', 'Timeless'),
#  ('Toronto Defiant', 'Team Peps'),
#  ('Toronto Defiant', 'Saints'),
#  ('Toronto Defiant', 'Atlanta Reign'),
#  ('Toronto Defiant', 'O2 Blast'),
#  ('Toronto Defiant', 'WISP'),
#  ('Toronto Defiant', 'Florida Mayhem'),
#  ('Toronto Defiant', 'Poker Face'),
#  ('Toronto Defiant', 'New York Excelsior'),
#  ('Toronto Defiant', 'Vegas Eternal'),
#  ('Toronto Defiant', 'Los Angeles Valiant'),
#  ('Toronto Defiant', 'Houston Outlaws'),
#  ('Toronto Defiant', 'Hangzhou Spark'),
#  ('Toronto Defiant', 'San Francisco Shock'),
#  ('Toronto Defiant', 'Seoul Dynasty'),
#  ('Vancouver Titans', 'Twisted Minds'),
#  ('Vancouver Titans', 'Trick Room'),
#  ('Vancouver Titans', 'Washington Justice'),
#  ('Vancouver Titans', 'Dallas Fuel'),
#  ('Vancouver Titans', 'Seoul Infernal'),
#  ('Vancouver Titans', 'Redbird Esports'),
#  ('Vancouver Titans', 'Dreamers'),
#  ('Vancouver Titans', 'Boston Uprising'),
#  ('Vancouver Titans', 'London Spitfire'),
#  ('Vancouver Titans', 'Shanghai Dragons'),
#  ('Vancouver Titans', 'Chengdu Hunters'),
#  ('Vancouver Titans', 'Guangzhou Charge'),
#  ('Vancouver Titans', 'PANTHERA'),
#  ('Vancouver Titans', 'Los Angeles Gladiators'),
#  ('Vancouver Titans', 'Rhodes'),
#  ('Vancouver Titans', 'Sin Prisa Gaming'),
#  ('Vancouver Titans', 'Timeless'),
#  ('Vancouver Titans', 'Team Peps'),
#  ('Vancouver Titans', 'Saints'),
#  ('Vancouver Titans', 'Atlanta Reign'),
#  ('Vancouver Titans', 'O2 Blast'),
#  ('Vancouver Titans', 'WISP'),
#  ('Vancouver Titans', 'Florida Mayhem'),
#  ('Vancouver Titans', 'Poker Face'),
#  ('Vancouver Titans', 'New York Excelsior'),
#  ('Vancouver Titans', 'Vegas Eternal'),
#  ('Vancouver Titans', 'Los Angeles Valiant'),
#  ('Vancouver Titans', 'Houston Outlaws'),
#  ('Vancouver Titans', 'Hangzhou Spark'),
#  ('Vancouver Titans', 'San Francisco Shock'),
#  ('Vancouver Titans', 'Seoul Dynasty'),
#  ('Twisted Minds', 'Trick Room'),
#  ('Twisted Minds', 'Washington Justice'),
#  ('Twisted Minds', 'Dallas Fuel'),
#  ('Twisted Minds', 'Seoul Infernal'),
#  ('Twisted Minds', 'Redbird Esports'),
#  ('Twisted Minds', 'Dreamers'),
#  ('Twisted Minds', 'Boston Uprising'),
#  ('Twisted Minds', 'London Spitfire'),
#  ('Twisted Minds', 'Shanghai Dragons'),
#  ('Twisted Minds', 'Chengdu Hunters'),
#  ('Twisted Minds', 'Guangzhou Charge'),
#  ('Twisted Minds', 'PANTHERA'),
#  ('Twisted Minds', 'Los Angeles Gladiators'),
#  ('Twisted Minds', 'Rhodes'),
#  ('Twisted Minds', 'Sin Prisa Gaming'),
#  ('Twisted Minds', 'Timeless'),
#  ('Twisted Minds', 'Team Peps'),
#  ('Twisted Minds', 'Saints'),
#  ('Twisted Minds', 'Atlanta Reign'),
#  ('Twisted Minds', 'O2 Blast'),
#  ('Twisted Minds', 'WISP'),
#  ('Twisted Minds', 'Florida Mayhem'),
#  ('Twisted Minds', 'Poker Face'),
#  ('Twisted Minds', 'New York Excelsior'),
#  ('Twisted Minds', 'Vegas Eternal'),
#  ('Twisted Minds', 'Los Angeles Valiant'),
#  ('Twisted Minds', 'Houston Outlaws'),
#  ('Twisted Minds', 'Hangzhou Spark'),
#  ('Twisted Minds', 'San Francisco Shock'),
#  ('Twisted Minds', 'Seoul Dynasty'),
#  ('Trick Room', 'Washington Justice'),
#  ('Trick Room', 'Dallas Fuel'),
#  ('Trick Room', 'Seoul Infernal'),
#  ('Trick Room', 'Redbird Esports'),
#  ('Trick Room', 'Dreamers'),
#  ('Trick Room', 'Boston Uprising'),
#  ('Trick Room', 'London Spitfire'),
#  ('Trick Room', 'Shanghai Dragons'),
#  ('Trick Room', 'Chengdu Hunters'),
#  ('Trick Room', 'Guangzhou Charge'),
#  ('Trick Room', 'PANTHERA'),
#  ('Trick Room', 'Los Angeles Gladiators'),
#  ('Trick Room', 'Rhodes'),
#  ('Trick Room', 'Sin Prisa Gaming'),
#  ('Trick Room', 'Timeless'),
#  ('Trick Room', 'Team Peps'),
#  ('Trick Room', 'Saints'),
#  ('Trick Room', 'Atlanta Reign'),
#  ('Trick Room', 'O2 Blast'),
#  ('Trick Room', 'WISP'),
#  ('Trick Room', 'Florida Mayhem'),
#  ('Trick Room', 'Poker Face'),
#  ('Trick Room', 'New York Excelsior'),
#  ('Trick Room', 'Vegas Eternal'),
#  ('Trick Room', 'Los Angeles Valiant'),
#  ('Trick Room', 'Houston Outlaws'),
#  ('Trick Room', 'Hangzhou Spark'),
#  ('Trick Room', 'San Francisco Shock'),
#  ('Trick Room', 'Seoul Dynasty'),
#  ('Washington Justice', 'Dallas Fuel'),
#  ('Washington Justice', 'Seoul Infernal'),
#  ('Washington Justice', 'Redbird Esports'),
#  ('Washington Justice', 'Dreamers'),
#  ('Washington Justice', 'Boston Uprising'),
#  ('Washington Justice', 'London Spitfire'),
#  ('Washington Justice', 'Shanghai Dragons'),
#  ('Washington Justice', 'Chengdu Hunters'),
#  ('Washington Justice', 'Guangzhou Charge'),
#  ('Washington Justice', 'PANTHERA'),
#  ('Washington Justice', 'Los Angeles Gladiators'),
#  ('Washington Justice', 'Rhodes'),
#  ('Washington Justice', 'Sin Prisa Gaming'),
#  ('Washington Justice', 'Timeless'),
#  ('Washington Justice', 'Team Peps'),
#  ('Washington Justice', 'Saints'),
#  ('Washington Justice', 'Atlanta Reign'),
#  ('Washington Justice', 'O2 Blast'),
#  ('Washington Justice', 'WISP'),
#  ('Washington Justice', 'Florida Mayhem'),
#  ('Washington Justice', 'Poker Face'),
#  ('Washington Justice', 'New York Excelsior'),
#  ('Washington Justice', 'Vegas Eternal'),
#  ('Washington Justice', 'Los Angeles Valiant'),
#  ('Washington Justice', 'Houston Outlaws'),
#  ('Washington Justice', 'Hangzhou Spark'),
#  ('Washington Justice', 'San Francisco Shock'),
#  ('Washington Justice', 'Seoul Dynasty'),
#  ('Dallas Fuel', 'Seoul Infernal'),
#  ('Dallas Fuel', 'Redbird Esports'),
#  ('Dallas Fuel', 'Dreamers'),
#  ('Dallas Fuel', 'Boston Uprising'),
#  ('Dallas Fuel', 'London Spitfire'),
#  ('Dallas Fuel', 'Shanghai Dragons'),
#  ('Dallas Fuel', 'Chengdu Hunters'),
#  ('Dallas Fuel', 'Guangzhou Charge'),
#  ('Dallas Fuel', 'PANTHERA'),
#  ('Dallas Fuel', 'Los Angeles Gladiators'),
#  ('Dallas Fuel', 'Rhodes'),
#  ('Dallas Fuel', 'Sin Prisa Gaming'),
#  ('Dallas Fuel', 'Timeless'),
#  ('Dallas Fuel', 'Team Peps'),
#  ('Dallas Fuel', 'Saints'),
#  ('Dallas Fuel', 'Atlanta Reign'),
#  ('Dallas Fuel', 'O2 Blast'),
#  ('Dallas Fuel', 'WISP'),
#  ('Dallas Fuel', 'Florida Mayhem'),
#  ('Dallas Fuel', 'Poker Face'),
#  ('Dallas Fuel', 'New York Excelsior'),
#  ('Dallas Fuel', 'Vegas Eternal'),
#  ('Dallas Fuel', 'Los Angeles Valiant'),
#  ('Dallas Fuel', 'Houston Outlaws'),
#  ('Dallas Fuel', 'Hangzhou Spark'),
#  ('Dallas Fuel', 'San Francisco Shock'),
#  ('Dallas Fuel', 'Seoul Dynasty'),
#  ('Seoul Infernal', 'Redbird Esports'),
#  ('Seoul Infernal', 'Dreamers'),
#  ('Seoul Infernal', 'Boston Uprising'),
#  ('Seoul Infernal', 'London Spitfire'),
#  ('Seoul Infernal', 'Shanghai Dragons'),
#  ('Seoul Infernal', 'Chengdu Hunters'),
#  ('Seoul Infernal', 'Guangzhou Charge'),
#  ('Seoul Infernal', 'PANTHERA'),
#  ('Seoul Infernal', 'Los Angeles Gladiators'),
#  ('Seoul Infernal', 'Rhodes'),
#  ('Seoul Infernal', 'Sin Prisa Gaming'),
#  ('Seoul Infernal', 'Timeless'),
#  ('Seoul Infernal', 'Team Peps'),
#  ('Seoul Infernal', 'Saints'),
#  ('Seoul Infernal', 'Atlanta Reign'),
#  ('Seoul Infernal', 'O2 Blast'),
#  ('Seoul Infernal', 'WISP'),
#  ('Seoul Infernal', 'Florida Mayhem'),
#  ('Seoul Infernal', 'Poker Face'),
#  ('Seoul Infernal', 'New York Excelsior'),
#  ('Seoul Infernal', 'Vegas Eternal'),
#  ('Seoul Infernal', 'Los Angeles Valiant'),
#  ('Seoul Infernal', 'Houston Outlaws'),
#  ('Seoul Infernal', 'Hangzhou Spark'),
#  ('Seoul Infernal', 'San Francisco Shock'),
#  ('Seoul Infernal', 'Seoul Dynasty'),
#  ('Redbird Esports', 'Dreamers'),
#  ('Redbird Esports', 'Boston Uprising'),
#  ('Redbird Esports', 'London Spitfire'),
#  ('Redbird Esports', 'Shanghai Dragons'),
#  ('Redbird Esports', 'Chengdu Hunters'),
#  ('Redbird Esports', 'Guangzhou Charge'),
#  ('Redbird Esports', 'PANTHERA'),
#  ('Redbird Esports', 'Los Angeles Gladiators'),
#  ('Redbird Esports', 'Rhodes'),
#  ('Redbird Esports', 'Sin Prisa Gaming'),
#  ('Redbird Esports', 'Timeless'),
#  ('Redbird Esports', 'Team Peps'),
#  ('Redbird Esports', 'Saints'),
#  ('Redbird Esports', 'Atlanta Reign'),
#  ('Redbird Esports', 'O2 Blast'),
#  ('Redbird Esports', 'WISP'),
#  ('Redbird Esports', 'Florida Mayhem'),
#  ('Redbird Esports', 'Poker Face'),
#  ('Redbird Esports', 'New York Excelsior'),
#  ('Redbird Esports', 'Vegas Eternal'),
#  ('Redbird Esports', 'Los Angeles Valiant'),
#  ('Redbird Esports', 'Houston Outlaws'),
#  ('Redbird Esports', 'Hangzhou Spark'),
#  ('Redbird Esports', 'San Francisco Shock'),
#  ('Redbird Esports', 'Seoul Dynasty'),
#  ('Dreamers', 'Boston Uprising'),
#  ('Dreamers', 'London Spitfire'),
#  ('Dreamers', 'Shanghai Dragons'),
#  ('Dreamers', 'Chengdu Hunters'),
#  ('Dreamers', 'Guangzhou Charge'),
#  ('Dreamers', 'PANTHERA'),
#  ('Dreamers', 'Los Angeles Gladiators'),
#  ('Dreamers', 'Rhodes'),
#  ('Dreamers', 'Sin Prisa Gaming'),
#  ('Dreamers', 'Timeless'),
#  ('Dreamers', 'Team Peps'),
#  ('Dreamers', 'Saints'),
#  ('Dreamers', 'Atlanta Reign'),
#  ('Dreamers', 'O2 Blast'),
#  ('Dreamers', 'WISP'),
#  ('Dreamers', 'Florida Mayhem'),
#  ('Dreamers', 'Poker Face'),
#  ('Dreamers', 'New York Excelsior'),
#  ('Dreamers', 'Vegas Eternal'),
#  ('Dreamers', 'Los Angeles Valiant'),
#  ('Dreamers', 'Houston Outlaws'),
#  ('Dreamers', 'Hangzhou Spark'),
#  ('Dreamers', 'San Francisco Shock'),
#  ('Dreamers', 'Seoul Dynasty'),
#  ('Boston Uprising', 'London Spitfire'),
#  ('Boston Uprising', 'Shanghai Dragons'),
#  ('Boston Uprising', 'Chengdu Hunters'),
#  ('Boston Uprising', 'Guangzhou Charge'),
#  ('Boston Uprising', 'PANTHERA'),
#  ('Boston Uprising', 'Los Angeles Gladiators'),
#  ('Boston Uprising', 'Rhodes'),
#  ('Boston Uprising', 'Sin Prisa Gaming'),
#  ('Boston Uprising', 'Timeless'),
#  ('Boston Uprising', 'Team Peps'),
#  ('Boston Uprising', 'Saints'),
#  ('Boston Uprising', 'Atlanta Reign'),
#  ('Boston Uprising', 'O2 Blast'),
#  ('Boston Uprising', 'WISP'),
#  ('Boston Uprising', 'Florida Mayhem'),
#  ('Boston Uprising', 'Poker Face'),
#  ('Boston Uprising', 'New York Excelsior'),
#  ('Boston Uprising', 'Vegas Eternal'),
#  ('Boston Uprising', 'Los Angeles Valiant'),
#  ('Boston Uprising', 'Houston Outlaws'),
#  ('Boston Uprising', 'Hangzhou Spark'),
#  ('Boston Uprising', 'San Francisco Shock'),
#  ('Boston Uprising', 'Seoul Dynasty'),
#  ('London Spitfire', 'Shanghai Dragons'),
#  ('London Spitfire', 'Chengdu Hunters'),
#  ('London Spitfire', 'Guangzhou Charge'),
#  ('London Spitfire', 'PANTHERA'),
#  ('London Spitfire', 'Los Angeles Gladiators'),
#  ('London Spitfire', 'Rhodes'),
#  ('London Spitfire', 'Sin Prisa Gaming'),
#  ('London Spitfire', 'Timeless'),
#  ('London Spitfire', 'Team Peps'),
#  ('London Spitfire', 'Saints'),
#  ('London Spitfire', 'Atlanta Reign'),
#  ('London Spitfire', 'O2 Blast'),
#  ('London Spitfire', 'WISP'),
#  ('London Spitfire', 'Florida Mayhem'),
#  ('London Spitfire', 'Poker Face'),
#  ('London Spitfire', 'New York Excelsior'),
#  ('London Spitfire', 'Vegas Eternal'),
#  ('London Spitfire', 'Los Angeles Valiant'),
#  ('London Spitfire', 'Houston Outlaws'),
#  ('London Spitfire', 'Hangzhou Spark'),
#  ('London Spitfire', 'San Francisco Shock'),
#  ('London Spitfire', 'Seoul Dynasty'),
#  ('Shanghai Dragons', 'Chengdu Hunters'),
#  ('Shanghai Dragons', 'Guangzhou Charge'),
#  ('Shanghai Dragons', 'PANTHERA'),
#  ('Shanghai Dragons', 'Los Angeles Gladiators'),
#  ('Shanghai Dragons', 'Rhodes'),
#  ('Shanghai Dragons', 'Sin Prisa Gaming'),
#  ('Shanghai Dragons', 'Timeless'),
#  ('Shanghai Dragons', 'Team Peps'),
#  ('Shanghai Dragons', 'Saints'),
#  ('Shanghai Dragons', 'Atlanta Reign'),
#  ('Shanghai Dragons', 'O2 Blast'),
#  ('Shanghai Dragons', 'WISP'),
#  ('Shanghai Dragons', 'Florida Mayhem'),
#  ('Shanghai Dragons', 'Poker Face'),
#  ('Shanghai Dragons', 'New York Excelsior'),
#  ('Shanghai Dragons', 'Vegas Eternal'),
#  ('Shanghai Dragons', 'Los Angeles Valiant'),
#  ('Shanghai Dragons', 'Houston Outlaws'),
#  ('Shanghai Dragons', 'Hangzhou Spark'),
#  ('Shanghai Dragons', 'San Francisco Shock'),
#  ('Shanghai Dragons', 'Seoul Dynasty'),
#  ('Chengdu Hunters', 'Guangzhou Charge'),
#  ('Chengdu Hunters', 'PANTHERA'),
#  ('Chengdu Hunters', 'Los Angeles Gladiators'),
#  ('Chengdu Hunters', 'Rhodes'),
#  ('Chengdu Hunters', 'Sin Prisa Gaming'),
#  ('Chengdu Hunters', 'Timeless'),
#  ('Chengdu Hunters', 'Team Peps'),
#  ('Chengdu Hunters', 'Saints'),
#  ('Chengdu Hunters', 'Atlanta Reign'),
#  ('Chengdu Hunters', 'O2 Blast'),
#  ('Chengdu Hunters', 'WISP'),
#  ('Chengdu Hunters', 'Florida Mayhem'),
#  ('Chengdu Hunters', 'Poker Face'),
#  ('Chengdu Hunters', 'New York Excelsior'),
#  ('Chengdu Hunters', 'Vegas Eternal'),
#  ('Chengdu Hunters', 'Los Angeles Valiant'),
#  ('Chengdu Hunters', 'Houston Outlaws'),
#  ('Chengdu Hunters', 'Hangzhou Spark'),
#  ('Chengdu Hunters', 'San Francisco Shock'),
#  ('Chengdu Hunters', 'Seoul Dynasty'),
#  ('Guangzhou Charge', 'PANTHERA'),
#  ('Guangzhou Charge', 'Los Angeles Gladiators'),
#  ('Guangzhou Charge', 'Rhodes'),
#  ('Guangzhou Charge', 'Sin Prisa Gaming'),
#  ('Guangzhou Charge', 'Timeless'),
#  ('Guangzhou Charge', 'Team Peps'),
#  ('Guangzhou Charge', 'Saints'),
#  ('Guangzhou Charge', 'Atlanta Reign'),
#  ('Guangzhou Charge', 'O2 Blast'),
#  ('Guangzhou Charge', 'WISP'),
#  ('Guangzhou Charge', 'Florida Mayhem'),
#  ('Guangzhou Charge', 'Poker Face'),
#  ('Guangzhou Charge', 'New York Excelsior'),
#  ('Guangzhou Charge', 'Vegas Eternal'),
#  ('Guangzhou Charge', 'Los Angeles Valiant'),
#  ('Guangzhou Charge', 'Houston Outlaws'),
#  ('Guangzhou Charge', 'Hangzhou Spark'),
#  ('Guangzhou Charge', 'San Francisco Shock'),
#  ('Guangzhou Charge', 'Seoul Dynasty'),
#  ('PANTHERA', 'Los Angeles Gladiators'),
#  ('PANTHERA', 'Rhodes'),
#  ('PANTHERA', 'Sin Prisa Gaming'),
#  ('PANTHERA', 'Timeless'),
#  ('PANTHERA', 'Team Peps'),
#  ('PANTHERA', 'Saints'),
#  ('PANTHERA', 'Atlanta Reign'),
#  ('PANTHERA', 'O2 Blast'),
#  ('PANTHERA', 'WISP'),
#  ('PANTHERA', 'Florida Mayhem'),
#  ('PANTHERA', 'Poker Face'),
#  ('PANTHERA', 'New York Excelsior'),
#  ('PANTHERA', 'Vegas Eternal'),
#  ('PANTHERA', 'Los Angeles Valiant'),
#  ('PANTHERA', 'Houston Outlaws'),
#  ('PANTHERA', 'Hangzhou Spark'),
#  ('PANTHERA', 'San Francisco Shock'),
#  ('PANTHERA', 'Seoul Dynasty'),
#  ('Los Angeles Gladiators', 'Rhodes'),
#  ('Los Angeles Gladiators', 'Sin Prisa Gaming'),
#  ('Los Angeles Gladiators', 'Timeless'),
#  ('Los Angeles Gladiators', 'Team Peps'),
#  ('Los Angeles Gladiators', 'Saints'),
#  ('Los Angeles Gladiators', 'Atlanta Reign'),
#  ('Los Angeles Gladiators', 'O2 Blast'),
#  ('Los Angeles Gladiators', 'WISP'),
#  ('Los Angeles Gladiators', 'Florida Mayhem'),
#  ('Los Angeles Gladiators', 'Poker Face'),
#  ('Los Angeles Gladiators', 'New York Excelsior'),
#  ('Los Angeles Gladiators', 'Vegas Eternal'),
#  ('Los Angeles Gladiators', 'Los Angeles Valiant'),
#  ('Los Angeles Gladiators', 'Houston Outlaws'),
#  ('Los Angeles Gladiators', 'Hangzhou Spark'),
#  ('Los Angeles Gladiators', 'San Francisco Shock'),
#  ('Los Angeles Gladiators', 'Seoul Dynasty'),
#  ('Rhodes', 'Sin Prisa Gaming'),
#  ('Rhodes', 'Timeless'),
#  ('Rhodes', 'Team Peps'),
#  ('Rhodes', 'Saints'),
#  ('Rhodes', 'Atlanta Reign'),
#  ('Rhodes', 'O2 Blast'),
#  ('Rhodes', 'WISP'),
#  ('Rhodes', 'Florida Mayhem'),
#  ('Rhodes', 'Poker Face'),
#  ('Rhodes', 'New York Excelsior'),
#  ('Rhodes', 'Vegas Eternal'),
#  ('Rhodes', 'Los Angeles Valiant'),
#  ('Rhodes', 'Houston Outlaws'),
#  ('Rhodes', 'Hangzhou Spark'),
#  ('Rhodes', 'San Francisco Shock'),
#  ('Rhodes', 'Seoul Dynasty'),
#  ('Sin Prisa Gaming', 'Timeless'),
#  ('Sin Prisa Gaming', 'Team Peps'),
#  ('Sin Prisa Gaming', 'Saints'),
#  ('Sin Prisa Gaming', 'Atlanta Reign'),
#  ('Sin Prisa Gaming', 'O2 Blast'),
#  ('Sin Prisa Gaming', 'WISP'),
#  ('Sin Prisa Gaming', 'Florida Mayhem'),
#  ('Sin Prisa Gaming', 'Poker Face'),
#  ('Sin Prisa Gaming', 'New York Excelsior'),
#  ('Sin Prisa Gaming', 'Vegas Eternal'),
#  ('Sin Prisa Gaming', 'Los Angeles Valiant'),
#  ('Sin Prisa Gaming', 'Houston Outlaws'),
#  ('Sin Prisa Gaming', 'Hangzhou Spark'),
#  ('Sin Prisa Gaming', 'San Francisco Shock'),
#  ('Sin Prisa Gaming', 'Seoul Dynasty'),
#  ('Timeless', 'Team Peps'),
#  ('Timeless', 'Saints'),
#  ('Timeless', 'Atlanta Reign'),
#  ('Timeless', 'O2 Blast'),
#  ('Timeless', 'WISP'),
#  ('Timeless', 'Florida Mayhem'),
#  ('Timeless', 'Poker Face'),
#  ('Timeless', 'New York Excelsior'),
#  ('Timeless', 'Vegas Eternal'),
#  ('Timeless', 'Los Angeles Valiant'),
#  ('Timeless', 'Houston Outlaws'),
#  ('Timeless', 'Hangzhou Spark'),
#  ('Timeless', 'San Francisco Shock'),
#  ('Timeless', 'Seoul Dynasty'),
#  ('Team Peps', 'Saints'),
#  ('Team Peps', 'Atlanta Reign'),
#  ('Team Peps', 'O2 Blast'),
#  ('Team Peps', 'WISP'),
#  ('Team Peps', 'Florida Mayhem'),
#  ('Team Peps', 'Poker Face'),
#  ('Team Peps', 'New York Excelsior'),
#  ('Team Peps', 'Vegas Eternal'),
#  ('Team Peps', 'Los Angeles Valiant'),
#  ('Team Peps', 'Houston Outlaws'),
#  ('Team Peps', 'Hangzhou Spark'),
#  ('Team Peps', 'San Francisco Shock'),
#  ('Team Peps', 'Seoul Dynasty'),
#  ('Saints', 'Atlanta Reign'),
#  ('Saints', 'O2 Blast'),
#  ('Saints', 'WISP'),
#  ('Saints', 'Florida Mayhem'),
#  ('Saints', 'Poker Face'),
#  ('Saints', 'New York Excelsior'),
#  ('Saints', 'Vegas Eternal'),
#  ('Saints', 'Los Angeles Valiant'),
#  ('Saints', 'Houston Outlaws'),
#  ('Saints', 'Hangzhou Spark'),
#  ('Saints', 'San Francisco Shock'),
#  ('Saints', 'Seoul Dynasty'),
#  ('Atlanta Reign', 'O2 Blast'),
#  ('Atlanta Reign', 'WISP'),
#  ('Atlanta Reign', 'Florida Mayhem'),
#  ('Atlanta Reign', 'Poker Face'),
#  ('Atlanta Reign', 'New York Excelsior'),
#  ('Atlanta Reign', 'Vegas Eternal'),
#  ('Atlanta Reign', 'Los Angeles Valiant'),
#  ('Atlanta Reign', 'Houston Outlaws'),
#  ('Atlanta Reign', 'Hangzhou Spark'),
#  ('Atlanta Reign', 'San Francisco Shock'),
#  ('Atlanta Reign', 'Seoul Dynasty'),
#  ('O2 Blast', 'WISP'),
#  ('O2 Blast', 'Florida Mayhem'),
#  ('O2 Blast', 'Poker Face'),
#  ('O2 Blast', 'New York Excelsior'),
#  ('O2 Blast', 'Vegas Eternal'),
#  ('O2 Blast', 'Los Angeles Valiant'),
#  ('O2 Blast', 'Houston Outlaws'),
#  ('O2 Blast', 'Hangzhou Spark'),
#  ('O2 Blast', 'San Francisco Shock'),
#  ('O2 Blast', 'Seoul Dynasty'),
#  ('WISP', 'Florida Mayhem'),
#  ('WISP', 'Poker Face'),
#  ('WISP', 'New York Excelsior'),
#  ('WISP', 'Vegas Eternal'),
#  ('WISP', 'Los Angeles Valiant'),
#  ('WISP', 'Houston Outlaws'),
#  ('WISP', 'Hangzhou Spark'),
#  ('WISP', 'San Francisco Shock'),
#  ('WISP', 'Seoul Dynasty'),
#  ('Florida Mayhem', 'Poker Face'),
#  ('Florida Mayhem', 'New York Excelsior'),
#  ('Florida Mayhem', 'Vegas Eternal'),
#  ('Florida Mayhem', 'Los Angeles Valiant'),
#  ('Florida Mayhem', 'Houston Outlaws'),
#  ('Florida Mayhem', 'Hangzhou Spark'),
#  ('Florida Mayhem', 'San Francisco Shock'),
#  ('Florida Mayhem', 'Seoul Dynasty'),
#  ('Poker Face', 'New York Excelsior'),
#  ('Poker Face', 'Vegas Eternal'),
#  ('Poker Face', 'Los Angeles Valiant'),
#  ('Poker Face', 'Houston Outlaws'),
#  ('Poker Face', 'Hangzhou Spark'),
#  ('Poker Face', 'San Francisco Shock'),
#  ('Poker Face', 'Seoul Dynasty'),
#  ('New York Excelsior', 'Vegas Eternal'),
#  ('New York Excelsior', 'Los Angeles Valiant'),
#  ('New York Excelsior', 'Houston Outlaws'),
#  ('New York Excelsior', 'Hangzhou Spark'),
#  ('New York Excelsior', 'San Francisco Shock'),
#  ('New York Excelsior', 'Seoul Dynasty'),
#  ('Vegas Eternal', 'Los Angeles Valiant'),
#  ('Vegas Eternal', 'Houston Outlaws'),
#  ('Vegas Eternal', 'Hangzhou Spark'),
#  ('Vegas Eternal', 'San Francisco Shock'),
#  ('Vegas Eternal', 'Seoul Dynasty'),
#  ('Los Angeles Valiant', 'Houston Outlaws'),
#  ('Los Angeles Valiant', 'Hangzhou Spark'),
#  ('Los Angeles Valiant', 'San Francisco Shock'),
#  ('Los Angeles Valiant', 'Seoul Dynasty'),
#  ('Houston Outlaws', 'Hangzhou Spark'),
#  ('Houston Outlaws', 'San Francisco Shock'),
#  ('Houston Outlaws', 'Seoul Dynasty'),
#  ('Hangzhou Spark', 'San Francisco Shock'),
#  ('Hangzhou Spark', 'Seoul Dynasty'),
#  ('San Francisco Shock', 'Seoul Dynasty')]

# %%
# with open("result.txt", mode="w", encoding="utf-8") as f:
#     for i in teams_matches:
#         f.write(f"{i}\n")
# f.close()

# %%
len(teams_matches)
# Out:
# 528
