# %% [markdown]
# ## Combinations for the tournament's matches between teams

# %%
import pandas as pd

# %% [markdown]
# #### cargar datos de la temporada 2023

# %%
df = pd.read_csv('Team Comp vs Opp Comp_the big cheese_data.csv')
df = df[df["Season"] > 2022]
df
# Out:
#                      team_name opponent (the big cheese) Result  \
# 413            Boston Uprising           Houston Outlaws   Loss
# 414            Boston Uprising             Vegas Eternal   Loss
# 415             Florida Mayhem           Boston Uprising   Loss
# 416           Guangzhou Charge          Shanghai Dragons    Win
# 417            Houston Outlaws            Florida Mayhem    Win
# ...                        ...                       ...    ...
# 848802      Washington Justice    Los Angeles Gladiators   Loss
# 848803              Trick Room          Vancouver Titans   Loss
# 848809      New York Excelsior        Washington Justice   Loss
# 848814      Washington Justice           Boston Uprising   Loss
# 848816  Los Angeles Gladiators           Boston Uprising   Loss
#
#                    map_name  Season
# 413     Antarctic Peninsula    2023
# 414     Antarctic Peninsula    2023
# 415     Antarctic Peninsula    2023
# 416     Antarctic Peninsula    2023
# 417     Antarctic Peninsula    2023
# ...                     ...     ...
# 848802  Antarctic Peninsula    2023
# 848803  Antarctic Peninsula    2023
# 848809  Antarctic Peninsula    2023
# 848814                Ilios    2023
# 848816  Antarctic Peninsula    2023
#
# [65519 rows x 5 columns]

# %%
team_names = set(df["team_name"])
team_names
# Out:
# {'Atlanta Reign',
#  'Boston Uprising',
#  'Dallas Fuel',
#  'Dreamers',
#  'Florida Mayhem',
#  'Guangzhou Charge',
#  'Hangzhou Spark',
#  'Houston Outlaws',
#  'London Spitfire',
#  'Los Angeles Gladiators',
#  'Los Angeles Valiant',
#  'New York Excelsior',
#  'O2 Blast',
#  'PANTHERA',
#  'Poker Face',
#  'Redbird Esports',
#  'Rhodes',
#  'Saints',
#  'San Francisco Shock',
#  'Seoul Dynasty',
#  'Seoul Infernal',
#  'Shanghai Dragons',
#  'Sin Prisa Gaming',
#  'Team Peps',
#  'Timeless',
#  'Toronto Defiant',
#  'Trick Room',
#  'Twisted Minds',
#  'Vancouver Titans',
#  'Vegas Eternal',
#  'WISP',
#  'Washington Justice'}

# %%
len(team_names)
# Out:
# 32

# %%
from itertools import combinations
teams_matches = list(combinations(team_names,r=2))
teams_matches
# Out:
# [('Seoul Infernal', 'Trick Room'),
#  ('Seoul Infernal', 'WISP'),
#  ('Seoul Infernal', 'Twisted Minds'),
#  ('Seoul Infernal', 'Saints'),
#  ('Seoul Infernal', 'Hangzhou Spark'),
#  ('Seoul Infernal', 'Team Peps'),
#  ('Seoul Infernal', 'Boston Uprising'),
#  ('Seoul Infernal', 'Poker Face'),
#  ('Seoul Infernal', 'Vegas Eternal'),
#  ('Seoul Infernal', 'San Francisco Shock'),
#  ('Seoul Infernal', 'Toronto Defiant'),
#  ('Seoul Infernal', 'Guangzhou Charge'),
#  ('Seoul Infernal', 'London Spitfire'),
#  ('Seoul Infernal', 'Dreamers'),
#  ('Seoul Infernal', 'O2 Blast'),
#  ('Seoul Infernal', 'Seoul Dynasty'),
#  ('Seoul Infernal', 'Shanghai Dragons'),
#  ('Seoul Infernal', 'Los Angeles Valiant'),
#  ('Seoul Infernal', 'PANTHERA'),
#  ('Seoul Infernal', 'Dallas Fuel'),
#  ('Seoul Infernal', 'Redbird Esports'),
#  ('Seoul Infernal', 'New York Excelsior'),
#  ('Seoul Infernal', 'Florida Mayhem'),
#  ('Seoul Infernal', 'Rhodes'),
#  ('Seoul Infernal', 'Houston Outlaws'),
#  ('Seoul Infernal', 'Atlanta Reign'),
#  ('Seoul Infernal', 'Washington Justice'),
#  ('Seoul Infernal', 'Los Angeles Gladiators'),
#  ('Seoul Infernal', 'Vancouver Titans'),
#  ('Seoul Infernal', 'Sin Prisa Gaming'),
#  ('Seoul Infernal', 'Timeless'),
#  ('Trick Room', 'WISP'),
#  ('Trick Room', 'Twisted Minds'),
#  ('Trick Room', 'Saints'),
#  ('Trick Room', 'Hangzhou Spark'),
#  ('Trick Room', 'Team Peps'),
#  ('Trick Room', 'Boston Uprising'),
#  ('Trick Room', 'Poker Face'),
#  ('Trick Room', 'Vegas Eternal'),
#  ('Trick Room', 'San Francisco Shock'),
#  ('Trick Room', 'Toronto Defiant'),
#  ('Trick Room', 'Guangzhou Charge'),
#  ('Trick Room', 'London Spitfire'),
#  ('Trick Room', 'Dreamers'),
#  ('Trick Room', 'O2 Blast'),
#  ('Trick Room', 'Seoul Dynasty'),
#  ('Trick Room', 'Shanghai Dragons'),
#  ('Trick Room', 'Los Angeles Valiant'),
#  ('Trick Room', 'PANTHERA'),
#  ('Trick Room', 'Dallas Fuel'),
#  ('Trick Room', 'Redbird Esports'),
#  ('Trick Room', 'New York Excelsior'),
#  ('Trick Room', 'Florida Mayhem'),
#  ('Trick Room', 'Rhodes'),
#  ('Trick Room', 'Houston Outlaws'),
#  ('Trick Room', 'Atlanta Reign'),
#  ('Trick Room', 'Washington Justice'),
#  ('Trick Room', 'Los Angeles Gladiators'),
#  ('Trick Room', 'Vancouver Titans'),
#  ('Trick Room', 'Sin Prisa Gaming'),
#  ('Trick Room', 'Timeless'),
#  ('WISP', 'Twisted Minds'),
#  ('WISP', 'Saints'),
#  ('WISP', 'Hangzhou Spark'),
#  ('WISP', 'Team Peps'),
#  ('WISP', 'Boston Uprising'),
#  ('WISP', 'Poker Face'),
#  ('WISP', 'Vegas Eternal'),
#  ('WISP', 'San Francisco Shock'),
#  ('WISP', 'Toronto Defiant'),
#  ('WISP', 'Guangzhou Charge'),
#  ('WISP', 'London Spitfire'),
#  ('WISP', 'Dreamers'),
#  ('WISP', 'O2 Blast'),
#  ('WISP', 'Seoul Dynasty'),
#  ('WISP', 'Shanghai Dragons'),
#  ('WISP', 'Los Angeles Valiant'),
#  ('WISP', 'PANTHERA'),
#  ('WISP', 'Dallas Fuel'),
#  ('WISP', 'Redbird Esports'),
#  ('WISP', 'New York Excelsior'),
#  ('WISP', 'Florida Mayhem'),
#  ('WISP', 'Rhodes'),
#  ('WISP', 'Houston Outlaws'),
#  ('WISP', 'Atlanta Reign'),
#  ('WISP', 'Washington Justice'),
#  ('WISP', 'Los Angeles Gladiators'),
#  ('WISP', 'Vancouver Titans'),
#  ('WISP', 'Sin Prisa Gaming'),
#  ('WISP', 'Timeless'),
#  ('Twisted Minds', 'Saints'),
#  ('Twisted Minds', 'Hangzhou Spark'),
#  ('Twisted Minds', 'Team Peps'),
#  ('Twisted Minds', 'Boston Uprising'),
#  ('Twisted Minds', 'Poker Face'),
#  ('Twisted Minds', 'Vegas Eternal'),
#  ('Twisted Minds', 'San Francisco Shock'),
#  ('Twisted Minds', 'Toronto Defiant'),
#  ('Twisted Minds', 'Guangzhou Charge'),
#  ('Twisted Minds', 'London Spitfire'),
#  ('Twisted Minds', 'Dreamers'),
#  ('Twisted Minds', 'O2 Blast'),
#  ('Twisted Minds', 'Seoul Dynasty'),
#  ('Twisted Minds', 'Shanghai Dragons'),
#  ('Twisted Minds', 'Los Angeles Valiant'),
#  ('Twisted Minds', 'PANTHERA'),
#  ('Twisted Minds', 'Dallas Fuel'),
#  ('Twisted Minds', 'Redbird Esports'),
#  ('Twisted Minds', 'New York Excelsior'),
#  ('Twisted Minds', 'Florida Mayhem'),
#  ('Twisted Minds', 'Rhodes'),
#  ('Twisted Minds', 'Houston Outlaws'),
#  ('Twisted Minds', 'Atlanta Reign'),
#  ('Twisted Minds', 'Washington Justice'),
#  ('Twisted Minds', 'Los Angeles Gladiators'),
#  ('Twisted Minds', 'Vancouver Titans'),
#  ('Twisted Minds', 'Sin Prisa Gaming'),
#  ('Twisted Minds', 'Timeless'),
#  ('Saints', 'Hangzhou Spark'),
#  ('Saints', 'Team Peps'),
#  ('Saints', 'Boston Uprising'),
#  ('Saints', 'Poker Face'),
#  ('Saints', 'Vegas Eternal'),
#  ('Saints', 'San Francisco Shock'),
#  ('Saints', 'Toronto Defiant'),
#  ('Saints', 'Guangzhou Charge'),
#  ('Saints', 'London Spitfire'),
#  ('Saints', 'Dreamers'),
#  ('Saints', 'O2 Blast'),
#  ('Saints', 'Seoul Dynasty'),
#  ('Saints', 'Shanghai Dragons'),
#  ('Saints', 'Los Angeles Valiant'),
#  ('Saints', 'PANTHERA'),
#  ('Saints', 'Dallas Fuel'),
#  ('Saints', 'Redbird Esports'),
#  ('Saints', 'New York Excelsior'),
#  ('Saints', 'Florida Mayhem'),
#  ('Saints', 'Rhodes'),
#  ('Saints', 'Houston Outlaws'),
#  ('Saints', 'Atlanta Reign'),
#  ('Saints', 'Washington Justice'),
#  ('Saints', 'Los Angeles Gladiators'),
#  ('Saints', 'Vancouver Titans'),
#  ('Saints', 'Sin Prisa Gaming'),
#  ('Saints', 'Timeless'),
#  ('Hangzhou Spark', 'Team Peps'),
#  ('Hangzhou Spark', 'Boston Uprising'),
#  ('Hangzhou Spark', 'Poker Face'),
#  ('Hangzhou Spark', 'Vegas Eternal'),
#  ('Hangzhou Spark', 'San Francisco Shock'),
#  ('Hangzhou Spark', 'Toronto Defiant'),
#  ('Hangzhou Spark', 'Guangzhou Charge'),
#  ('Hangzhou Spark', 'London Spitfire'),
#  ('Hangzhou Spark', 'Dreamers'),
#  ('Hangzhou Spark', 'O2 Blast'),
#  ('Hangzhou Spark', 'Seoul Dynasty'),
#  ('Hangzhou Spark', 'Shanghai Dragons'),
#  ('Hangzhou Spark', 'Los Angeles Valiant'),
#  ('Hangzhou Spark', 'PANTHERA'),
#  ('Hangzhou Spark', 'Dallas Fuel'),
#  ('Hangzhou Spark', 'Redbird Esports'),
#  ('Hangzhou Spark', 'New York Excelsior'),
#  ('Hangzhou Spark', 'Florida Mayhem'),
#  ('Hangzhou Spark', 'Rhodes'),
#  ('Hangzhou Spark', 'Houston Outlaws'),
#  ('Hangzhou Spark', 'Atlanta Reign'),
#  ('Hangzhou Spark', 'Washington Justice'),
#  ('Hangzhou Spark', 'Los Angeles Gladiators'),
#  ('Hangzhou Spark', 'Vancouver Titans'),
#  ('Hangzhou Spark', 'Sin Prisa Gaming'),
#  ('Hangzhou Spark', 'Timeless'),
#  ('Team Peps', 'Boston Uprising'),
#  ('Team Peps', 'Poker Face'),
#  ('Team Peps', 'Vegas Eternal'),
#  ('Team Peps', 'San Francisco Shock'),
#  ('Team Peps', 'Toronto Defiant'),
#  ('Team Peps', 'Guangzhou Charge'),
#  ('Team Peps', 'London Spitfire'),
#  ('Team Peps', 'Dreamers'),
#  ('Team Peps', 'O2 Blast'),
#  ('Team Peps', 'Seoul Dynasty'),
#  ('Team Peps', 'Shanghai Dragons'),
#  ('Team Peps', 'Los Angeles Valiant'),
#  ('Team Peps', 'PANTHERA'),
#  ('Team Peps', 'Dallas Fuel'),
#  ('Team Peps', 'Redbird Esports'),
#  ('Team Peps', 'New York Excelsior'),
#  ('Team Peps', 'Florida Mayhem'),
#  ('Team Peps', 'Rhodes'),
#  ('Team Peps', 'Houston Outlaws'),
#  ('Team Peps', 'Atlanta Reign'),
#  ('Team Peps', 'Washington Justice'),
#  ('Team Peps', 'Los Angeles Gladiators'),
#  ('Team Peps', 'Vancouver Titans'),
#  ('Team Peps', 'Sin Prisa Gaming'),
#  ('Team Peps', 'Timeless'),
#  ('Boston Uprising', 'Poker Face'),
#  ('Boston Uprising', 'Vegas Eternal'),
#  ('Boston Uprising', 'San Francisco Shock'),
#  ('Boston Uprising', 'Toronto Defiant'),
#  ('Boston Uprising', 'Guangzhou Charge'),
#  ('Boston Uprising', 'London Spitfire'),
#  ('Boston Uprising', 'Dreamers'),
#  ('Boston Uprising', 'O2 Blast'),
#  ('Boston Uprising', 'Seoul Dynasty'),
#  ('Boston Uprising', 'Shanghai Dragons'),
#  ('Boston Uprising', 'Los Angeles Valiant'),
#  ('Boston Uprising', 'PANTHERA'),
#  ('Boston Uprising', 'Dallas Fuel'),
#  ('Boston Uprising', 'Redbird Esports'),
#  ('Boston Uprising', 'New York Excelsior'),
#  ('Boston Uprising', 'Florida Mayhem'),
#  ('Boston Uprising', 'Rhodes'),
#  ('Boston Uprising', 'Houston Outlaws'),
#  ('Boston Uprising', 'Atlanta Reign'),
#  ('Boston Uprising', 'Washington Justice'),
#  ('Boston Uprising', 'Los Angeles Gladiators'),
#  ('Boston Uprising', 'Vancouver Titans'),
#  ('Boston Uprising', 'Sin Prisa Gaming'),
#  ('Boston Uprising', 'Timeless'),
#  ('Poker Face', 'Vegas Eternal'),
#  ('Poker Face', 'San Francisco Shock'),
#  ('Poker Face', 'Toronto Defiant'),
#  ('Poker Face', 'Guangzhou Charge'),
#  ('Poker Face', 'London Spitfire'),
#  ('Poker Face', 'Dreamers'),
#  ('Poker Face', 'O2 Blast'),
#  ('Poker Face', 'Seoul Dynasty'),
#  ('Poker Face', 'Shanghai Dragons'),
#  ('Poker Face', 'Los Angeles Valiant'),
#  ('Poker Face', 'PANTHERA'),
#  ('Poker Face', 'Dallas Fuel'),
#  ('Poker Face', 'Redbird Esports'),
#  ('Poker Face', 'New York Excelsior'),
#  ('Poker Face', 'Florida Mayhem'),
#  ('Poker Face', 'Rhodes'),
#  ('Poker Face', 'Houston Outlaws'),
#  ('Poker Face', 'Atlanta Reign'),
#  ('Poker Face', 'Washington Justice'),
#  ('Poker Face', 'Los Angeles Gladiators'),
#  ('Poker Face', 'Vancouver Titans'),
#  ('Poker Face', 'Sin Prisa Gaming'),
#  ('Poker Face', 'Timeless'),
#  ('Vegas Eternal', 'San Francisco Shock'),
#  ('Vegas Eternal', 'Toronto Defiant'),
#  ('Vegas Eternal', 'Guangzhou Charge'),
#  ('Vegas Eternal', 'London Spitfire'),
#  ('Vegas Eternal', 'Dreamers'),
#  ('Vegas Eternal', 'O2 Blast'),
#  ('Vegas Eternal', 'Seoul Dynasty'),
#  ('Vegas Eternal', 'Shanghai Dragons'),
#  ('Vegas Eternal', 'Los Angeles Valiant'),
#  ('Vegas Eternal', 'PANTHERA'),
#  ('Vegas Eternal', 'Dallas Fuel'),
#  ('Vegas Eternal', 'Redbird Esports'),
#  ('Vegas Eternal', 'New York Excelsior'),
#  ('Vegas Eternal', 'Florida Mayhem'),
#  ('Vegas Eternal', 'Rhodes'),
#  ('Vegas Eternal', 'Houston Outlaws'),
#  ('Vegas Eternal', 'Atlanta Reign'),
#  ('Vegas Eternal', 'Washington Justice'),
#  ('Vegas Eternal', 'Los Angeles Gladiators'),
#  ('Vegas Eternal', 'Vancouver Titans'),
#  ('Vegas Eternal', 'Sin Prisa Gaming'),
#  ('Vegas Eternal', 'Timeless'),
#  ('San Francisco Shock', 'Toronto Defiant'),
#  ('San Francisco Shock', 'Guangzhou Charge'),
#  ('San Francisco Shock', 'London Spitfire'),
#  ('San Francisco Shock', 'Dreamers'),
#  ('San Francisco Shock', 'O2 Blast'),
#  ('San Francisco Shock', 'Seoul Dynasty'),
#  ('San Francisco Shock', 'Shanghai Dragons'),
#  ('San Francisco Shock', 'Los Angeles Valiant'),
#  ('San Francisco Shock', 'PANTHERA'),
#  ('San Francisco Shock', 'Dallas Fuel'),
#  ('San Francisco Shock', 'Redbird Esports'),
#  ('San Francisco Shock', 'New York Excelsior'),
#  ('San Francisco Shock', 'Florida Mayhem'),
#  ('San Francisco Shock', 'Rhodes'),
#  ('San Francisco Shock', 'Houston Outlaws'),
#  ('San Francisco Shock', 'Atlanta Reign'),
#  ('San Francisco Shock', 'Washington Justice'),
#  ('San Francisco Shock', 'Los Angeles Gladiators'),
#  ('San Francisco Shock', 'Vancouver Titans'),
#  ('San Francisco Shock', 'Sin Prisa Gaming'),
#  ('San Francisco Shock', 'Timeless'),
#  ('Toronto Defiant', 'Guangzhou Charge'),
#  ('Toronto Defiant', 'London Spitfire'),
#  ('Toronto Defiant', 'Dreamers'),
#  ('Toronto Defiant', 'O2 Blast'),
#  ('Toronto Defiant', 'Seoul Dynasty'),
#  ('Toronto Defiant', 'Shanghai Dragons'),
#  ('Toronto Defiant', 'Los Angeles Valiant'),
#  ('Toronto Defiant', 'PANTHERA'),
#  ('Toronto Defiant', 'Dallas Fuel'),
#  ('Toronto Defiant', 'Redbird Esports'),
#  ('Toronto Defiant', 'New York Excelsior'),
#  ('Toronto Defiant', 'Florida Mayhem'),
#  ('Toronto Defiant', 'Rhodes'),
#  ('Toronto Defiant', 'Houston Outlaws'),
#  ('Toronto Defiant', 'Atlanta Reign'),
#  ('Toronto Defiant', 'Washington Justice'),
#  ('Toronto Defiant', 'Los Angeles Gladiators'),
#  ('Toronto Defiant', 'Vancouver Titans'),
#  ('Toronto Defiant', 'Sin Prisa Gaming'),
#  ('Toronto Defiant', 'Timeless'),
#  ('Guangzhou Charge', 'London Spitfire'),
#  ('Guangzhou Charge', 'Dreamers'),
#  ('Guangzhou Charge', 'O2 Blast'),
#  ('Guangzhou Charge', 'Seoul Dynasty'),
#  ('Guangzhou Charge', 'Shanghai Dragons'),
#  ('Guangzhou Charge', 'Los Angeles Valiant'),
#  ('Guangzhou Charge', 'PANTHERA'),
#  ('Guangzhou Charge', 'Dallas Fuel'),
#  ('Guangzhou Charge', 'Redbird Esports'),
#  ('Guangzhou Charge', 'New York Excelsior'),
#  ('Guangzhou Charge', 'Florida Mayhem'),
#  ('Guangzhou Charge', 'Rhodes'),
#  ('Guangzhou Charge', 'Houston Outlaws'),
#  ('Guangzhou Charge', 'Atlanta Reign'),
#  ('Guangzhou Charge', 'Washington Justice'),
#  ('Guangzhou Charge', 'Los Angeles Gladiators'),
#  ('Guangzhou Charge', 'Vancouver Titans'),
#  ('Guangzhou Charge', 'Sin Prisa Gaming'),
#  ('Guangzhou Charge', 'Timeless'),
#  ('London Spitfire', 'Dreamers'),
#  ('London Spitfire', 'O2 Blast'),
#  ('London Spitfire', 'Seoul Dynasty'),
#  ('London Spitfire', 'Shanghai Dragons'),
#  ('London Spitfire', 'Los Angeles Valiant'),
#  ('London Spitfire', 'PANTHERA'),
#  ('London Spitfire', 'Dallas Fuel'),
#  ('London Spitfire', 'Redbird Esports'),
#  ('London Spitfire', 'New York Excelsior'),
#  ('London Spitfire', 'Florida Mayhem'),
#  ('London Spitfire', 'Rhodes'),
#  ('London Spitfire', 'Houston Outlaws'),
#  ('London Spitfire', 'Atlanta Reign'),
#  ('London Spitfire', 'Washington Justice'),
#  ('London Spitfire', 'Los Angeles Gladiators'),
#  ('London Spitfire', 'Vancouver Titans'),
#  ('London Spitfire', 'Sin Prisa Gaming'),
#  ('London Spitfire', 'Timeless'),
#  ('Dreamers', 'O2 Blast'),
#  ('Dreamers', 'Seoul Dynasty'),
#  ('Dreamers', 'Shanghai Dragons'),
#  ('Dreamers', 'Los Angeles Valiant'),
#  ('Dreamers', 'PANTHERA'),
#  ('Dreamers', 'Dallas Fuel'),
#  ('Dreamers', 'Redbird Esports'),
#  ('Dreamers', 'New York Excelsior'),
#  ('Dreamers', 'Florida Mayhem'),
#  ('Dreamers', 'Rhodes'),
#  ('Dreamers', 'Houston Outlaws'),
#  ('Dreamers', 'Atlanta Reign'),
#  ('Dreamers', 'Washington Justice'),
#  ('Dreamers', 'Los Angeles Gladiators'),
#  ('Dreamers', 'Vancouver Titans'),
#  ('Dreamers', 'Sin Prisa Gaming'),
#  ('Dreamers', 'Timeless'),
#  ('O2 Blast', 'Seoul Dynasty'),
#  ('O2 Blast', 'Shanghai Dragons'),
#  ('O2 Blast', 'Los Angeles Valiant'),
#  ('O2 Blast', 'PANTHERA'),
#  ('O2 Blast', 'Dallas Fuel'),
#  ('O2 Blast', 'Redbird Esports'),
#  ('O2 Blast', 'New York Excelsior'),
#  ('O2 Blast', 'Florida Mayhem'),
#  ('O2 Blast', 'Rhodes'),
#  ('O2 Blast', 'Houston Outlaws'),
#  ('O2 Blast', 'Atlanta Reign'),
#  ('O2 Blast', 'Washington Justice'),
#  ('O2 Blast', 'Los Angeles Gladiators'),
#  ('O2 Blast', 'Vancouver Titans'),
#  ('O2 Blast', 'Sin Prisa Gaming'),
#  ('O2 Blast', 'Timeless'),
#  ('Seoul Dynasty', 'Shanghai Dragons'),
#  ('Seoul Dynasty', 'Los Angeles Valiant'),
#  ('Seoul Dynasty', 'PANTHERA'),
#  ('Seoul Dynasty', 'Dallas Fuel'),
#  ('Seoul Dynasty', 'Redbird Esports'),
#  ('Seoul Dynasty', 'New York Excelsior'),
#  ('Seoul Dynasty', 'Florida Mayhem'),
#  ('Seoul Dynasty', 'Rhodes'),
#  ('Seoul Dynasty', 'Houston Outlaws'),
#  ('Seoul Dynasty', 'Atlanta Reign'),
#  ('Seoul Dynasty', 'Washington Justice'),
#  ('Seoul Dynasty', 'Los Angeles Gladiators'),
#  ('Seoul Dynasty', 'Vancouver Titans'),
#  ('Seoul Dynasty', 'Sin Prisa Gaming'),
#  ('Seoul Dynasty', 'Timeless'),
#  ('Shanghai Dragons', 'Los Angeles Valiant'),
#  ('Shanghai Dragons', 'PANTHERA'),
#  ('Shanghai Dragons', 'Dallas Fuel'),
#  ('Shanghai Dragons', 'Redbird Esports'),
#  ('Shanghai Dragons', 'New York Excelsior'),
#  ('Shanghai Dragons', 'Florida Mayhem'),
#  ('Shanghai Dragons', 'Rhodes'),
#  ('Shanghai Dragons', 'Houston Outlaws'),
#  ('Shanghai Dragons', 'Atlanta Reign'),
#  ('Shanghai Dragons', 'Washington Justice'),
#  ('Shanghai Dragons', 'Los Angeles Gladiators'),
#  ('Shanghai Dragons', 'Vancouver Titans'),
#  ('Shanghai Dragons', 'Sin Prisa Gaming'),
#  ('Shanghai Dragons', 'Timeless'),
#  ('Los Angeles Valiant', 'PANTHERA'),
#  ('Los Angeles Valiant', 'Dallas Fuel'),
#  ('Los Angeles Valiant', 'Redbird Esports'),
#  ('Los Angeles Valiant', 'New York Excelsior'),
#  ('Los Angeles Valiant', 'Florida Mayhem'),
#  ('Los Angeles Valiant', 'Rhodes'),
#  ('Los Angeles Valiant', 'Houston Outlaws'),
#  ('Los Angeles Valiant', 'Atlanta Reign'),
#  ('Los Angeles Valiant', 'Washington Justice'),
#  ('Los Angeles Valiant', 'Los Angeles Gladiators'),
#  ('Los Angeles Valiant', 'Vancouver Titans'),
#  ('Los Angeles Valiant', 'Sin Prisa Gaming'),
#  ('Los Angeles Valiant', 'Timeless'),
#  ('PANTHERA', 'Dallas Fuel'),
#  ('PANTHERA', 'Redbird Esports'),
#  ('PANTHERA', 'New York Excelsior'),
#  ('PANTHERA', 'Florida Mayhem'),
#  ('PANTHERA', 'Rhodes'),
#  ('PANTHERA', 'Houston Outlaws'),
#  ('PANTHERA', 'Atlanta Reign'),
#  ('PANTHERA', 'Washington Justice'),
#  ('PANTHERA', 'Los Angeles Gladiators'),
#  ('PANTHERA', 'Vancouver Titans'),
#  ('PANTHERA', 'Sin Prisa Gaming'),
#  ('PANTHERA', 'Timeless'),
#  ('Dallas Fuel', 'Redbird Esports'),
#  ('Dallas Fuel', 'New York Excelsior'),
#  ('Dallas Fuel', 'Florida Mayhem'),
#  ('Dallas Fuel', 'Rhodes'),
#  ('Dallas Fuel', 'Houston Outlaws'),
#  ('Dallas Fuel', 'Atlanta Reign'),
#  ('Dallas Fuel', 'Washington Justice'),
#  ('Dallas Fuel', 'Los Angeles Gladiators'),
#  ('Dallas Fuel', 'Vancouver Titans'),
#  ('Dallas Fuel', 'Sin Prisa Gaming'),
#  ('Dallas Fuel', 'Timeless'),
#  ('Redbird Esports', 'New York Excelsior'),
#  ('Redbird Esports', 'Florida Mayhem'),
#  ('Redbird Esports', 'Rhodes'),
#  ('Redbird Esports', 'Houston Outlaws'),
#  ('Redbird Esports', 'Atlanta Reign'),
#  ('Redbird Esports', 'Washington Justice'),
#  ('Redbird Esports', 'Los Angeles Gladiators'),
#  ('Redbird Esports', 'Vancouver Titans'),
#  ('Redbird Esports', 'Sin Prisa Gaming'),
#  ('Redbird Esports', 'Timeless'),
#  ('New York Excelsior', 'Florida Mayhem'),
#  ('New York Excelsior', 'Rhodes'),
#  ('New York Excelsior', 'Houston Outlaws'),
#  ('New York Excelsior', 'Atlanta Reign'),
#  ('New York Excelsior', 'Washington Justice'),
#  ('New York Excelsior', 'Los Angeles Gladiators'),
#  ('New York Excelsior', 'Vancouver Titans'),
#  ('New York Excelsior', 'Sin Prisa Gaming'),
#  ('New York Excelsior', 'Timeless'),
#  ('Florida Mayhem', 'Rhodes'),
#  ('Florida Mayhem', 'Houston Outlaws'),
#  ('Florida Mayhem', 'Atlanta Reign'),
#  ('Florida Mayhem', 'Washington Justice'),
#  ('Florida Mayhem', 'Los Angeles Gladiators'),
#  ('Florida Mayhem', 'Vancouver Titans'),
#  ('Florida Mayhem', 'Sin Prisa Gaming'),
#  ('Florida Mayhem', 'Timeless'),
#  ('Rhodes', 'Houston Outlaws'),
#  ('Rhodes', 'Atlanta Reign'),
#  ('Rhodes', 'Washington Justice'),
#  ('Rhodes', 'Los Angeles Gladiators'),
#  ('Rhodes', 'Vancouver Titans'),
#  ('Rhodes', 'Sin Prisa Gaming'),
#  ('Rhodes', 'Timeless'),
#  ('Houston Outlaws', 'Atlanta Reign'),
#  ('Houston Outlaws', 'Washington Justice'),
#  ('Houston Outlaws', 'Los Angeles Gladiators'),
#  ('Houston Outlaws', 'Vancouver Titans'),
#  ('Houston Outlaws', 'Sin Prisa Gaming'),
#  ('Houston Outlaws', 'Timeless'),
#  ('Atlanta Reign', 'Washington Justice'),
#  ('Atlanta Reign', 'Los Angeles Gladiators'),
#  ('Atlanta Reign', 'Vancouver Titans'),
#  ('Atlanta Reign', 'Sin Prisa Gaming'),
#  ('Atlanta Reign', 'Timeless'),
#  ('Washington Justice', 'Los Angeles Gladiators'),
#  ('Washington Justice', 'Vancouver Titans'),
#  ('Washington Justice', 'Sin Prisa Gaming'),
#  ('Washington Justice', 'Timeless'),
#  ('Los Angeles Gladiators', 'Vancouver Titans'),
#  ('Los Angeles Gladiators', 'Sin Prisa Gaming'),
#  ('Los Angeles Gladiators', 'Timeless'),
#  ('Vancouver Titans', 'Sin Prisa Gaming'),
#  ('Vancouver Titans', 'Timeless'),
#  ('Sin Prisa Gaming', 'Timeless')]

# %%
# esto solo sirve para ver la lista completa
 
# with open("teams.txt", mode="w", encoding="utf-8") as f:
#     for i in team_names:
#     #for i in teams_matches:
#         f.write(f"{i}\n")
# f.close()

# %%
len(teams_matches)
# Out:
# 496

# %%
titans_matches = [("Vancouver Titans", i) for i in team_names if i != "Vancouver Titans"]
titans_matches
# Out:
# [('Vancouver Titans', 'Seoul Infernal'),
#  ('Vancouver Titans', 'Trick Room'),
#  ('Vancouver Titans', 'WISP'),
#  ('Vancouver Titans', 'Twisted Minds'),
#  ('Vancouver Titans', 'Saints'),
#  ('Vancouver Titans', 'Hangzhou Spark'),
#  ('Vancouver Titans', 'Team Peps'),
#  ('Vancouver Titans', 'Boston Uprising'),
#  ('Vancouver Titans', 'Poker Face'),
#  ('Vancouver Titans', 'Vegas Eternal'),
#  ('Vancouver Titans', 'San Francisco Shock'),
#  ('Vancouver Titans', 'Toronto Defiant'),
#  ('Vancouver Titans', 'Guangzhou Charge'),
#  ('Vancouver Titans', 'London Spitfire'),
#  ('Vancouver Titans', 'Dreamers'),
#  ('Vancouver Titans', 'O2 Blast'),
#  ('Vancouver Titans', 'Seoul Dynasty'),
#  ('Vancouver Titans', 'Shanghai Dragons'),
#  ('Vancouver Titans', 'Los Angeles Valiant'),
#  ('Vancouver Titans', 'PANTHERA'),
#  ('Vancouver Titans', 'Dallas Fuel'),
#  ('Vancouver Titans', 'Redbird Esports'),
#  ('Vancouver Titans', 'New York Excelsior'),
#  ('Vancouver Titans', 'Florida Mayhem'),
#  ('Vancouver Titans', 'Rhodes'),
#  ('Vancouver Titans', 'Houston Outlaws'),
#  ('Vancouver Titans', 'Atlanta Reign'),
#  ('Vancouver Titans', 'Washington Justice'),
#  ('Vancouver Titans', 'Los Angeles Gladiators'),
#  ('Vancouver Titans', 'Sin Prisa Gaming'),
#  ('Vancouver Titans', 'Timeless')]
